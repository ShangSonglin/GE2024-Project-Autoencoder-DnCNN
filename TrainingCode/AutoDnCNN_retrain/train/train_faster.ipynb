# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torch.nn.init as init

# 定义ConvAutoencoder和DnCNN模型
class ConvAutoencoder(nn.Module):
    def __init__(self):
        super(ConvAutoencoder, self).__init__()
        # 编码器
        self.encoder = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=3, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
            nn.ReLU()
        )
        # 解码器
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(64, 1, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

class DnCNN(nn.Module):
    def __init__(self, depth=17, n_channels=64, image_channels=1, use_bnorm=True, kernel_size=3):
        super(DnCNN, self).__init__()
        padding = 1
        layers = [
            nn.Conv2d(in_channels=image_channels, out_channels=n_channels, kernel_size=kernel_size, padding=padding),
            nn.ReLU(inplace=True)
        ]
        for _ in range(depth - 2):
            layers.extend([
                nn.Conv2d(n_channels, n_channels, kernel_size=kernel_size, padding=padding, bias=False),
                nn.BatchNorm2d(n_channels, eps=1e-4, momentum=0.95),
                nn.ReLU(inplace=True)
            ])
        layers.append(nn.Conv2d(n_channels, image_channels, kernel_size=kernel_size, padding=padding, bias=False))
        self.dncnn = nn.Sequential(*layers)
        self._initialize_weights()

    def forward(self, x):
        return x - self.dncnn(x)

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                init.orthogonal_(m.weight)
                if m.bias is not None:
                    init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                init.constant_(m.weight, 1)
                init.constant_(m.bias, 0)

# 检测 GPU 可用性
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def save_model(model, path):
    torch.save(model.state_dict(), path)

def load_model(model, path):
    if os.path.exists(path):
        model.load_state_dict(torch.load(path))
        print(f"Model loaded from {path}")
    return model

def train_and_test_models():
    num_epochs = 10
    batch_size = 64
    learning_rate = 0.001

    # 数据预处理和加载数据集
    transform = transforms.Compose([
        transforms.Grayscale(),
        transforms.Resize((32, 32)),
        transforms.RandomRotation(10),
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,))
    ])
    dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)

    print(f"Dataset size: {len(dataset)}")
    print(f"Batch size: {batch_size}")

    # 初始化模型
    autoencoder_model = ConvAutoencoder().to(device)
    dncnn_model = DnCNN(depth=35, n_channels=128).to(device)

    # 如果存在权重文件则加载
    autoencoder_model = load_model(autoencoder_model, 'autoencoder_weights.pth')
    dncnn_model = load_model(dncnn_model, 'dncnn_weights.pth')

    # 优化器和调度器
    optimizer_autoencoder = optim.Adam(autoencoder_model.parameters(), lr=learning_rate)
    optimizer_dncnn = optim.Adam(dncnn_model.parameters(), lr=learning_rate)
    scheduler_autoencoder = optim.lr_scheduler.StepLR(optimizer_autoencoder, step_size=5, gamma=0.5)
    scheduler_dncnn = optim.lr_scheduler.StepLR(optimizer_dncnn, step_size=5, gamma=0.5)

    criterion = nn.MSELoss()

    for epoch in range(num_epochs):
        autoencoder_model.train()
        dncnn_model.train()
        total_autoencoder_loss = 0.0
        total_dncnn_loss = 0.0

        for batch_idx, (clean_images, _) in enumerate(dataloader):
            clean_images = clean_images.to(device)
            noisy_images = clean_images + torch.randn_like(clean_images) * 0.3
            noisy_images = torch.clamp(noisy_images, 0., 1.)

            # 自动编码器去噪
            optimizer_autoencoder.zero_grad()
            autoencoder_outputs = autoencoder_model(noisy_images)
            loss_autoencoder = criterion(autoencoder_outputs, clean_images)
            loss_autoencoder.backward()
            optimizer_autoencoder.step()
            total_autoencoder_loss += loss_autoencoder.item()

            # DnCNN去噪
            optimizer_dncnn.zero_grad()
            dncnn_outputs = dncnn_model(noisy_images)
            loss_dncnn = criterion(dncnn_outputs, clean_images)
            loss_dncnn.backward()
            optimizer_dncnn.step()
            total_dncnn_loss += loss_dncnn.item()

            if batch_idx % 100 == 0:
                print(f"Epoch [{epoch + 1}/{num_epochs}], Batch [{batch_idx}/{len(dataloader)}] ")
                print(f"Autoencoder Loss: {loss_autoencoder.item():.4f}, DnCNN Loss: {loss_dncnn.item():.4f}")

        scheduler_autoencoder.step()
        scheduler_dncnn.step()

        # 保存模型权重
        save_model(autoencoder_model, 'autoencoder_weights.pth')
        save_model(dncnn_model, 'dncnn_weights.pth')

        print(f"Epoch [{epoch + 1}/{num_epochs}] Completed | Autoencoder Avg Loss: {total_autoencoder_loss / len(dataloader):.4f} | DnCNN Avg Loss: {total_dncnn_loss / len(dataloader):.4f}")

if __name__ == '__main__':
    train_and_test_models()
# Out:
# Dataset size: 60000
# Batch size: 64
# Epoch [1/10], Batch [0/938]
# Autoencoder Loss: 1.7167, DnCNN Loss: 1.8671
# Epoch [1/10], Batch [100/938]
# Autoencoder Loss: 0.8890, DnCNN Loss: 0.0176
# Epoch [1/10], Batch [200/938]
# Autoencoder Loss: 0.8807, DnCNN Loss: 0.0173
# Epoch [1/10], Batch [300/938]
# Autoencoder Loss: 0.8789, DnCNN Loss: 0.0158
# Epoch [1/10], Batch [400/938]
# Autoencoder Loss: 0.8836, DnCNN Loss: 0.0156
# Epoch [1/10], Batch [500/938]
# Autoencoder Loss: 0.8833, DnCNN Loss: 0.0145
# Epoch [1/10], Batch [600/938]
# Autoencoder Loss: 0.8741, DnCNN Loss: 0.0158
# Epoch [1/10], Batch [700/938]
# Autoencoder Loss: 0.8781, DnCNN Loss: 0.0160
# Epoch [1/10], Batch [800/938]
# Autoencoder Loss: 0.8838, DnCNN Loss: 0.0149
# Epoch [1/10], Batch [900/938]
# Autoencoder Loss: 0.8836, DnCNN Loss: 0.0135
# Epoch [1/10] Completed | Autoencoder Avg Loss: 0.8865 | DnCNN Avg Loss: 0.0244
# Epoch [2/10], Batch [0/938]
# Autoencoder Loss: 0.8762, DnCNN Loss: 0.0135
# Epoch [2/10], Batch [100/938]
# Autoencoder Loss: 0.8785, DnCNN Loss: 0.0134
# Epoch [2/10], Batch [200/938]
# Autoencoder Loss: 0.8814, DnCNN Loss: 0.0180
# Epoch [2/10], Batch [300/938]
# Autoencoder Loss: 0.8778, DnCNN Loss: 0.0132
# Epoch [2/10], Batch [400/938]
# Autoencoder Loss: 0.8800, DnCNN Loss: 0.0126
# Epoch [2/10], Batch [500/938]
# Autoencoder Loss: 0.8843, DnCNN Loss: 0.0122
# Epoch [2/10], Batch [600/938]
# Autoencoder Loss: 0.8813, DnCNN Loss: 0.0107
# Epoch [2/10], Batch [700/938]
# Autoencoder Loss: 0.8803, DnCNN Loss: 0.0108
# Epoch [2/10], Batch [800/938]
# Autoencoder Loss: 0.8759, DnCNN Loss: 0.0102
# Epoch [2/10], Batch [900/938]
# Autoencoder Loss: 0.8770, DnCNN Loss: 0.0110
# Epoch [2/10] Completed | Autoencoder Avg Loss: 0.8797 | DnCNN Avg Loss: 0.0122
# Epoch [3/10], Batch [0/938]
# Autoencoder Loss: 0.8789, DnCNN Loss: 0.0108
# Epoch [3/10], Batch [100/938]
# Autoencoder Loss: 0.8743, DnCNN Loss: 0.0100
# Epoch [3/10], Batch [200/938]
# Autoencoder Loss: 0.8830, DnCNN Loss: 0.0095
# Epoch [3/10], Batch [300/938]
# Autoencoder Loss: 0.8861, DnCNN Loss: 0.0092
# Epoch [3/10], Batch [400/938]
# Autoencoder Loss: 0.8772, DnCNN Loss: 0.0099
# Epoch [3/10], Batch [500/938]
# Autoencoder Loss: 0.8824, DnCNN Loss: 0.0087
# Epoch [3/10], Batch [600/938]
# Autoencoder Loss: 0.8870, DnCNN Loss: 0.0095
# Epoch [3/10], Batch [700/938]
# Autoencoder Loss: 0.8862, DnCNN Loss: 0.0092
# Epoch [3/10], Batch [800/938]
# Autoencoder Loss: 0.8844, DnCNN Loss: 0.0086
# Epoch [3/10], Batch [900/938]
# Autoencoder Loss: 0.8822, DnCNN Loss: 0.0089
# Epoch [3/10] Completed | Autoencoder Avg Loss: 0.8797 | DnCNN Avg Loss: 0.0097
# Epoch [4/10], Batch [0/938]
# Autoencoder Loss: 0.8850, DnCNN Loss: 0.0097
# Epoch [4/10], Batch [100/938]
# Autoencoder Loss: 0.8760, DnCNN Loss: 0.0089
# Epoch [4/10], Batch [200/938]
# Autoencoder Loss: 0.8746, DnCNN Loss: 0.0099
# Epoch [4/10], Batch [300/938]
# Autoencoder Loss: 0.8817, DnCNN Loss: 0.0090
# Epoch [4/10], Batch [400/938]
# Autoencoder Loss: 0.8789, DnCNN Loss: 0.0095
# Epoch [4/10], Batch [500/938]
# Autoencoder Loss: 0.8779, DnCNN Loss: 0.0090
# Epoch [4/10], Batch [600/938]
# Autoencoder Loss: 0.8893, DnCNN Loss: 0.0083
# Epoch [4/10], Batch [700/938]
# Autoencoder Loss: 0.8854, DnCNN Loss: 0.0086
# Epoch [4/10], Batch [800/938]
# Autoencoder Loss: 0.8805, DnCNN Loss: 0.0089
# Epoch [4/10], Batch [900/938]
# Autoencoder Loss: 0.8771, DnCNN Loss: 0.0086
# Epoch [4/10] Completed | Autoencoder Avg Loss: 0.8797 | DnCNN Avg Loss: 0.0092
# Epoch [5/10], Batch [0/938]
# Autoencoder Loss: 0.8755, DnCNN Loss: 0.0089
# Epoch [5/10], Batch [100/938]
# Autoencoder Loss: 0.8820, DnCNN Loss: 0.0084
# Epoch [5/10], Batch [200/938]
# Autoencoder Loss: 0.8809, DnCNN Loss: 0.0093
# Epoch [5/10], Batch [300/938]
# Autoencoder Loss: 0.8806, DnCNN Loss: 0.0100
# Epoch [5/10], Batch [400/938]
# Autoencoder Loss: 0.8795, DnCNN Loss: 0.0085
# Epoch [5/10], Batch [500/938]
# Autoencoder Loss: 0.8757, DnCNN Loss: 0.0087
# Epoch [5/10], Batch [600/938]
# Autoencoder Loss: 0.8814, DnCNN Loss: 0.0083
# Epoch [5/10], Batch [700/938]
# Autoencoder Loss: 0.8719, DnCNN Loss: 0.0091
# Epoch [5/10], Batch [800/938]
# Autoencoder Loss: 0.8782, DnCNN Loss: 0.0085
# Epoch [5/10], Batch [900/938]
# Autoencoder Loss: 0.8805, DnCNN Loss: 0.0092
# Epoch [5/10] Completed | Autoencoder Avg Loss: 0.8797 | DnCNN Avg Loss: 0.0088
# Epoch [6/10], Batch [0/938]
# Autoencoder Loss: 0.8819, DnCNN Loss: 0.0084
# Epoch [6/10], Batch [100/938]
# Autoencoder Loss: 0.8812, DnCNN Loss: 0.0097
# Epoch [6/10], Batch [200/938]
# Autoencoder Loss: 0.8725, DnCNN Loss: 0.0091
# Epoch [6/10], Batch [300/938]
# Autoencoder Loss: 0.8830, DnCNN Loss: 0.0078
# Epoch [6/10], Batch [400/938]
# Autoencoder Loss: 0.8841, DnCNN Loss: 0.0082
# Epoch [6/10], Batch [500/938]
# Autoencoder Loss: 0.8748, DnCNN Loss: 0.0084
# Epoch [6/10], Batch [600/938]
# Autoencoder Loss: 0.8840, DnCNN Loss: 0.0076
# Epoch [6/10], Batch [700/938]
# Autoencoder Loss: 0.8814, DnCNN Loss: 0.0076
# Epoch [6/10], Batch [800/938]
# Autoencoder Loss: 0.8810, DnCNN Loss: 0.0079
# Epoch [6/10], Batch [900/938]
# Autoencoder Loss: 0.8844, DnCNN Loss: 0.0081
# Epoch [7/10], Batch [700/938]
# Autoencoder Loss: 0.8778, DnCNN Loss: 0.0080
# Epoch [7/10], Batch [800/938]
# Autoencoder Loss: 0.8819, DnCNN Loss: 0.0075
# Epoch [7/10], Batch [900/938]
# Autoencoder Loss: 0.8806, DnCNN Loss: 0.0073
# Epoch [7/10] Completed | Autoencoder Avg Loss: 0.8797 | DnCNN Avg Loss: 0.0080
# Epoch [8/10], Batch [0/938]
# Autoencoder Loss: 0.8785, DnCNN Loss: 0.0074
# Epoch [8/10], Batch [100/938]
# Autoencoder Loss: 0.8836, DnCNN Loss: 0.0081
# Epoch [8/10], Batch [200/938]
# Autoencoder Loss: 0.8859, DnCNN Loss: 0.0077
# Epoch [8/10], Batch [300/938]
# Autoencoder Loss: 0.8788, DnCNN Loss: 0.0079
# Epoch [8/10], Batch [400/938]
# Autoencoder Loss: 0.8772, DnCNN Loss: 0.0087
# Epoch [8/10], Batch [500/938]
# Autoencoder Loss: 0.8767, DnCNN Loss: 0.0081
# Epoch [8/10], Batch [600/938]
# Autoencoder Loss: 0.8824, DnCNN Loss: 0.0071
# Epoch [8/10], Batch [700/938]
# Autoencoder Loss: 0.8750, DnCNN Loss: 0.0079
# Epoch [8/10], Batch [800/938]
# Autoencoder Loss: 0.8777, DnCNN Loss: 0.0082
# Epoch [8/10], Batch [900/938]
# Autoencoder Loss: 0.8798, DnCNN Loss: 0.0075
# Epoch [8/10] Completed | Autoencoder Avg Loss: 0.8797 | DnCNN Avg Loss: 0.0080
# Epoch [9/10], Batch [0/938]
# Autoencoder Loss: 0.8806, DnCNN Loss: 0.0077
# Epoch [9/10], Batch [100/938]
# Autoencoder Loss: 0.8802, DnCNN Loss: 0.0077
# Epoch [9/10], Batch [200/938]
# Autoencoder Loss: 0.8791, DnCNN Loss: 0.0083
# Epoch [9/10], Batch [300/938]
# Autoencoder Loss: 0.8821, DnCNN Loss: 0.0080
# Epoch [9/10], Batch [400/938]
# Autoencoder Loss: 0.8830, DnCNN Loss: 0.0076
# Epoch [9/10], Batch [500/938]
# Autoencoder Loss: 0.8804, DnCNN Loss: 0.0073
# Epoch [9/10], Batch [600/938]
# Autoencoder Loss: 0.8796, DnCNN Loss: 0.0074
# Epoch [9/10], Batch [700/938]
# Autoencoder Loss: 0.8821, DnCNN Loss: 0.0079
# Epoch [9/10], Batch [800/938]
# Autoencoder Loss: 0.8803, DnCNN Loss: 0.0076
# Epoch [9/10], Batch [900/938]
# Autoencoder Loss: 0.8782, DnCNN Loss: 0.0083
# Epoch [9/10] Completed | Autoencoder Avg Loss: 0.8797 | DnCNN Avg Loss: 0.0079
# Epoch [10/10], Batch [0/938]
# Autoencoder Loss: 0.8792, DnCNN Loss: 0.0076
# Epoch [10/10], Batch [100/938]
# Autoencoder Loss: 0.8777, DnCNN Loss: 0.0076
# Epoch [10/10], Batch [200/938]
# Autoencoder Loss: 0.8804, DnCNN Loss: 0.0074
# Epoch [10/10], Batch [300/938]
# Autoencoder Loss: 0.8730, DnCNN Loss: 0.0079
# Epoch [10/10], Batch [400/938]
# Autoencoder Loss: 0.8774, DnCNN Loss: 0.0079
# Epoch [10/10], Batch [500/938]
# Autoencoder Loss: 0.8761, DnCNN Loss: 0.0082
# Epoch [10/10], Batch [600/938]
# Autoencoder Loss: 0.8824, DnCNN Loss: 0.0070
# Epoch [10/10], Batch [700/938]
# Autoencoder Loss: 0.8861, DnCNN Loss: 0.0073
# Epoch [10/10], Batch [800/938]
# Autoencoder Loss: 0.8831, DnCNN Loss: 0.0072
# Epoch [10/10], Batch [900/938]
# Autoencoder Loss: 0.8803, DnCNN Loss: 0.0074
# Epoch [10/10] Completed | Autoencoder Avg Loss: 0.8797 | DnCNN Avg Loss: 0.0077
